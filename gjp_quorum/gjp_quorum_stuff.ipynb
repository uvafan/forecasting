# %%
import pandas as pd

def get_weekly_curve(country, col):
    df = pd.read_csv(f'../data/worldometers/{country}.csv')
    weekly_amts = []
    for week_end in range(len(df)-1, 6, -7):
        weekly_amts.append(df.at[week_end,col] - df.at[week_end-7,col])
    return list(reversed(weekly_amts))

countries = ['france','italy','japan','sk','spain','us']

death_curves = {}
case_curves = {}
for country in countries:
    death_curves[country] = get_weekly_curve(country, 'coronavirus-deaths-linear')
    case_curves[country] = get_weekly_curve(country, 'coronavirus-cases-linear')

death_curves
# Out:
# {'france': [1, 2, 44, 216, 1067, 2701, 6837, 6298, 4173, 2747],
#  'italy': [12, 95, 720, 2151, 4525, 5652, 4514, 3976, 3440, 2597],
#  'japan': [2, 3, 9, 14, 16, 12, 37, 84, 121, 114],
#  'sk': [12, 23, 25, 24, 42, 39, 35, 25, 13, 8],
#  'spain': [0, 0, 17, 277, 1478, 5031, 5838, 4568, 3244, 2737],
#  'us': [0, 11, 27, 133, 1089, 5134, 11297, 15021, 15182, 13761]}

# %%
case_curves
# Out:
# {'france': [6, 267, 1996, 6853, 16099, 31756, 46072, 30583, 22300, 10476],
#  'italy': [467, 2619, 9373, 23251, 38673, 36188, 28848, 25733, 22172, 16264],
#  'japan': [88, 159, 308, 275, 393, 1077, 2283, 3959, 3324, 1945],
#  'sk': [1203, 4360, 2134, 658, 724, 750, 497, 207, 103, 67],
#  'spain': [0, 82, 590, 7314, 20780, 51342, 51536, 35185, 31843, 27955],
#  'us': [45, 98, 1143, 8016, 59588, 151390, 221274, 210905, 201911, 209809]}

# %%
import matplotlib.pyplot as plt
for d in death_curves:
    plt.plot(death_curves[d])
plt.legend(death_curves.keys())
plt.show()

# %%
for c in death_curves:
    plt.plot(case_curves[c])
plt.legend(death_curves.keys())
plt.show()
