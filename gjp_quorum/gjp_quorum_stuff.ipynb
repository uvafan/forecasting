# %%
import pandas as pd

def get_weekly_curve(country, col):
    df = pd.read_csv(f'../data/worldometers/{country}.csv')
    weekly_amts = []
    for week_end in range(len(df)-1, 6, -7):
        weekly_amts.append(df.at[week_end,col] - df.at[week_end-7,col])
    return list(reversed(weekly_amts))

countries = ['france','italy','japan','sk','spain','us', 'india', 'brazil']

death_curves = {}
case_curves = {}
for country in countries:
    death_curves[country] = get_weekly_curve(country, 'coronavirus-deaths-linear')
    case_curves[country] = get_weekly_curve(country, 'coronavirus-cases-linear')

death_curves
# Out:
# {'france': [0, 1, 17, 108, 547, 1932, 5472, 6315, 5325, 3138, 2039],
#  'italy': [3, 38, 325, 1443, 3667, 5303, 5108, 4012, 3761, 2984, 2240],
#  'japan': [0, 5, 1, 17, 17, 13, 31, 38, 113, 136, 115],
#  'sk': [6, 15, 29, 25, 29, 48, 31, 31, 20, 8, 8],
#  'spain': [0, 0, 17, 277, 1478, 5031, 5838, 4568, 3244, 2737, 2074],
#  'us': [0, 1, 21, 51, 436, 2742, 8542, 13996, 15112, 14511, 13186],
#  'india': [0, 0, 0, 2, 5, 20, 91, 213, 228, 322, 510],
#  'brazil': [0, 0, 0, 4, 55, 183, 578, 937, 1149]}

# %%
case_curves
# Out:
# {'france': [0,
#   118,
#   1079,
#   4214,
#   10595,
#   24156,
#   47545,
#   32914,
#   27211,
#   14256,
#   6593],
#  'italy': [154,
#   1544,
#   5674,
#   17372,
#   34391,
#   38551,
#   31259,
#   27415,
#   22609,
#   18703,
#   13042],
#  'japan': [87, 110, 246, 331, 268, 765, 1788, 3716, 3427, 2652, 1428],
#  'sk': [573, 3134, 3577, 849, 735, 686, 654, 275, 149, 67, 65],
#  'spain': [0, 82, 590, 7314, 20780, 51342, 51536, 35185, 31843, 27955, 20493],
#  'us': [20,
#   40,
#   466,
#   3076,
#   30223,
#   111140,
#   198767,
#   223961,
#   202306,
#   217146,
#   200962],
#  'india': [0, 0, 37, 74, 282, 628, 3265, 4916, 8410, 10275, 14615],
#  'brazil': [1, 2, 49, 477, 2025, 4326, 9308, 12422, 17147]}

# %%
import matplotlib.pyplot as plt
for d in death_curves:
    plt.plot(death_curves[d])
plt.legend(death_curves.keys())
plt.show()

# %%
for c in death_curves:
    plt.plot(case_curves[c])
plt.legend(death_curves.keys())
plt.show()
